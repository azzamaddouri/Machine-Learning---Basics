# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
import openpyxl

# %%
dataframe_sample = pd.read_excel('homeprices.xlsx')
dataframe_sample
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area(sqr ft)')
plt.ylabel('price(US$)')
plt.scatter(dataframe_sample.area,dataframe_sample.price, color='blue', marker='*')
plt.plot(dataframe_sample.area, reg.predict(dataframe_sample[['area']].values), color = 'red')

# %%
# y = ay + b , dependent var = coeff * feature + intercept
reg = linear_model.LinearRegression()
# Training dataframe
reg.fit(dataframe_sample[['area']].values, dataframe_sample.price)
# Out:
# LinearRegression()

# %%
# Predict
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
# Gradient (a value)
reg.coef_
# Out:
# array([135.78767123])

# %%
# b value
reg.intercept_
# Out:
# 180616.43835616432

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
df = pd.read_excel('areas.xlsx')
df.head(3)
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200

# %%
p= reg.predict(df.values)

# %%
df['prices'] = p
df
# Out:
#    area         prices
# 0  2600  533664.383562
# 1  3000  587979.452055
# 2  3200  615136.986301
# 3  3600  669452.054795
# 4  4000  723767.123288

# %%
df.to_csv("prediction.csv", index= False)

# %%
import pickle

# %%
with open('model_pickle','wb') as f:
    pickle.dump(reg, f)

# %%
with open('model_pickle', 'rb') as f:
    mp = pickle.load(f)

# %%
mp.predict([[5000]])
# Out:
# array([859554.79452055])
